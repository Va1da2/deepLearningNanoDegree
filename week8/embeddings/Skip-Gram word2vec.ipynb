# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like translations.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with language and words, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time
import math

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to covert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
from collections import Counter
import random

threshold = 1e-5
word_counts = Counter(int_words)
total_count = len(int_words)
freqs = {word: count/total_count for word, count in word_counts.items()}
p_drop = {word: 1 - np.sqrt(threshold/freqs[word]) for word in word_counts}
train_words = [word for word in int_words if p_drop[word] < random.random()]

# %%
print('Subsampled words with t=1e-5: {0}'.format(len(train_words)))
print('Total words in the original list: {0}'.format(len(int_words)))
# Out:
# Subsampled words with t=1e-5: 4628950
# Total words in the original list: 16680599

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    # Your code here
    c = random.randint(1, window_size+1)
    ind1 = 0 if (idx - c < 0) else idx - c
    ind2 = idx + c
    target_words = set(words[ind1:idx] + words[idx+1:ind2+1])
    
    return list(target_words)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From Chris McCormick's blog, we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as one-hot encoded vectors. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. This weight matrix is usually called the embedding matrix or embedding look-up table. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name = 'inputs')
    labels = tf.placeholder(tf.int32, [None, None], name = 'labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of neurons in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using one-hot encoded vectors for our inputs. When you do the matrix multiplication of the one-hot vector with the embedding matrix, you end up selecting only one row out of the entire matrix:
#
# ![one-hot matrix multiplication](assets/matrix_mult_w_one_hot.png)
#
# You don't actually need to do the matrix multiplication, you just need to select the row in the embedding matrix that corresponds to the input word. Then, the embedding matrix becomes a lookup table, you're looking up a vector the size of the hidden layer that represents the input word.
#
# <img src="assets/word2vec_weight_matrix_lookup_table.png" width=500>
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform). This [TensorFlow tutorial](https://www.tensorflow.org/tutorials/word2vec) will help if you get stuck.

# %%
n_vocab = len(int_to_vocab)
n_embedding = 200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1.0, 1.0)) # create embedding weight matrix here
    embed = tf.nn.embedding_lookup(embedding, inputs) # use tf.nn.embedding_lookup to get the hidden layer output

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal([n_vocab, n_embedding], stddev=1.0))# create softmax weight matrix here
    softmax_b = tf.Variable(tf.zeros([n_vocab])) # create softmax biases here
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, labels, embed, n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 17.9318 0.4665 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 17.6901 0.3980 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 17.4460 0.4106 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 17.4516 0.4380 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 17.1919 0.5703 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 17.0923 0.5290 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 17.0306 0.4664 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 16.9533 0.4424 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 16.7865 0.4085 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 16.6497 0.4053 sec/batch
# Nearest to most: anacletus, lysosomes, maximized, spondees, collingridge, peacefully, nascent, heliopause,
# Nearest to but: millay, gendered, increases, prespa, kornbluth, eponymously, supposing, repay,
# Nearest to for: adolescence, humankind, senatus, rotherhithe, hin, cabin, forsaken, bohemians,
# Nearest to as: nh, toll, polemics, maintenance, bancroft, headshot, snow, pps,
# Nearest to this: motivational, solemnity, picchi, schlick, raaf, austral, jirga, gregers,
# Nearest to system: risch, baird, fairhair, participated, instructional, bohlen, aspartame, tyrolean,
# Nearest to they: firstly, hypothesizing, ciuszko, hancock, synods, packets, vegetarianism, mismatched,
# Nearest to some: greats, cyaxares, sputnik, remedied, paterson, theresa, grimmett, hercule,
# Nearest to units: lollards, acquisitions, seto, payroll, eurovision, discs, jref, presume,
# Nearest to hit: haldeman, bowled, canvases, maestro, unrestricted, priesthoods, conde, simca,
# Nearest to rise: fucked, delray, equ, described, innovation, christoph, belgae, chunnel,
# Nearest to stage: definition, opponents, hopelessness, caria, dieu, gattaca, crankshaft, taman,
# Nearest to articles: constituting, warmer, budokai, waterston, outdoors, fittingly, arrivals, trappers,
# Nearest to taking: minos, cavaliers, danny, acylation, override, court, establishment, habermas,
# Nearest to quite: rowed, nau, elective, dillinger, malky, arar, traore, serrano,
# Nearest to recorded: kumasi, factors, toes, dictate, spellings, miraculous, lab, lucie,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 16.5389 0.4281 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 16.4087 0.4478 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 16.3416 0.3861 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 16.1973 0.3829 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 16.0115 0.3816 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 15.9400 0.3848 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 15.8974 0.3763 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 15.7253 0.3780 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 15.6088 0.3849 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 15.5680 0.3850 sec/batch
# Nearest to most: anacletus, maximized, lysosomes, spondees, collingridge, disobey, nascent, critically,
# Nearest to but: millay, prespa, kornbluth, gendered, increases, eponymously, partake, multiplicity,
# Nearest to for: adolescence, senatus, hin, rotherhithe, humankind, bohemians, sunyaev, cabin,
# Nearest to as: nh, snow, polemics, toll, maintenance, bancroft, headshot, pps,
# Nearest to this: motivational, solemnity, picchi, schlick, raaf, austral, slowness, gregers,
# Nearest to system: baird, risch, fairhair, instructional, participated, bohlen, aspartame, tyrolean,
# Nearest to they: firstly, hypothesizing, hancock, synods, ciuszko, vegetarianism, retelling, minstrel,
# Nearest to some: cyaxares, sputnik, paterson, grimmett, greats, manipulate, remedied, theresa,
# Nearest to units: lollards, acquisitions, seto, payroll, presume, discs, fingerprinting, eurovision,
# Nearest to hit: haldeman, bowled, canvases, conde, unrestricted, maestro, priesthoods, simca,
# Nearest to rise: fucked, delray, equ, described, innovation, christoph, belgae, chunnel,
# Nearest to stage: definition, opponents, hopelessness, caria, dieu, gattaca, rushdie, taman,
# Nearest to articles: constituting, warmer, budokai, fittingly, waterston, deneuve, outdoors, trappers,
# Nearest to taking: acylation, danny, habermas, minos, cavaliers, court, override, establishment,
# Nearest to quite: rowed, nau, malky, dillinger, arar, elective, traore, unprecedented,
# Nearest to recorded: kumasi, factors, toes, dictate, lucie, lab, bamileke, spellings,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 15.4204 0.3929 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 15.2973 0.3982 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 15.2759 0.4029 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 15.1642 0.3908 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 14.9778 0.3901 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 14.9208 0.3950 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 14.7832 0.3860 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 14.7268 0.3748 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 14.6286 0.3773 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 14.6309 0.3801 sec/batch
# Nearest to most: maximized, anacletus, lysosomes, spondees, collingridge, disobey, nascent, manure,
# Nearest to but: millay, prespa, kornbluth, prices, supposing, eponymously, increases, excise,
# Nearest to for: senatus, adolescence, humankind, rotherhithe, hin, bohemians, forsaken, functioned,
# Nearest to as: polemics, nh, maintenance, headshot, alone, toll, pps, firepower,
# Nearest to this: solemnity, motivational, picchi, schlick, raaf, sandworm, austral, gregers,
# Nearest to system: baird, risch, fairhair, instructional, aspartame, bohlen, eyewitnesses, participated,
# Nearest to they: hypothesizing, hancock, firstly, synods, retelling, ciuszko, packets, mismatched,
# Nearest to some: sputnik, cyaxares, paterson, grimmett, moons, theresa, remedied, manipulate,
# Nearest to units: lollards, payroll, acquisitions, seto, discs, presume, sprinkling, includes,
# Nearest to hit: haldeman, bowled, canvases, conde, unrestricted, maestro, kiribati, tears,
# Nearest to rise: fucked, equ, delray, described, innovation, christoph, shout, belgae,
# Nearest to stage: definition, caria, dieu, hopelessness, opponents, unicode, gattaca, taman,
# Nearest to articles: constituting, budokai, warmer, waterston, outdoors, fittingly, deneuve, trappers,
# Nearest to taking: acylation, danny, cavaliers, minos, habermas, establishment, auratus, court,
# Nearest to quite: rowed, nau, malky, unprecedented, arar, serrano, traore, dillinger,
# Nearest to recorded: kumasi, factors, toes, lucie, dictate, lab, bamileke, connotes,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 14.4478 0.3889 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 14.4093 0.3786 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 14.3065 0.3781 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 14.1520 0.3767 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 14.1211 0.3884 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 13.9836 0.3788 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 13.9080 0.3789 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 13.8891 0.3763 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 13.6766 0.3754 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 13.6312 0.3752 sec/batch
# Nearest to most: maximized, anacletus, spondees, disobey, lysosomes, nascent, collingridge, shared,
# Nearest to but: supposing, prespa, inferiority, region, millay, kornbluth, excise, prices,
# Nearest to for: capsid, adolescence, senatus, functioned, auc, forsaken, cabin, rotherhithe,
# Nearest to as: polemics, alone, maintenance, nh, utopian, headshot, pps, toll,
# Nearest to this: solemnity, motivational, schlick, picchi, sandworm, unsaturated, hedwig, butcher,
# Nearest to system: baird, fairhair, risch, instructional, tyrolean, bohlen, participated, illuminism,
# Nearest to they: hypothesizing, firstly, hancock, brighton, vegetarianism, ciuszko, minstrel, packets,
# Nearest to some: sputnik, cyaxares, grimmett, paterson, theresa, manipulate, tsarevich, moons,
# Nearest to units: lollards, payroll, acquisitions, seto, discs, presume, stapleton, mit,
# Nearest to hit: haldeman, bowled, unrestricted, conde, kiribati, canvases, maestro, tears,
# Nearest to rise: fucked, equ, delray, described, innovation, belgae, christoph, disarmed,
# Nearest to stage: definition, hopelessness, caria, opponents, unicode, dieu, gattaca, taman,
# Nearest to articles: constituting, budokai, warmer, won, waterston, oblique, deneuve, trappers,
# Nearest to taking: minos, danny, cavaliers, acylation, establishment, auratus, confided, court,
# Nearest to quite: rowed, unprecedented, nau, malky, elective, serrano, arar, dillinger,
# Nearest to recorded: kumasi, factors, toes, lucie, dictate, lab, bamileke, connotes,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 13.5945 0.3789 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 13.5276 0.3790 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 13.3950 0.3854 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 13.3141 0.3772 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 13.2643 0.3895 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 13.1747 0.3779 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 13.0265 0.2798 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 12.9158 0.3841 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 12.8567 0.3823 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 12.7094 0.3818 sec/batch
# Nearest to most: maximized, spondees, and, disobey, lysosomes, fis, ancestors, collingridge,
# Nearest to but: on, supposing, prespa, region, excise, inferiority, low, the,
# Nearest to for: a, by, of, capsid, s, to, the, auc,
# Nearest to as: of, by, alone, and, a, the, petroleum, to,
# Nearest to this: solemnity, motivational, calm, picchi, sandworm, congresses, aleksey, injunction,
# Nearest to system: fairhair, baird, risch, participated, aspartame, tyrolean, illuminism, eyewitnesses,
# Nearest to they: hypothesizing, hancock, minstrel, ciuszko, receded, firstly, retelling, irrational,
# Nearest to some: sputnik, grimmett, cyaxares, paterson, tsarevich, swimmer, petra, moons,
# Nearest to units: lollards, payroll, acquisitions, seto, discs, presume, stapleton, uther,
# Nearest to hit: haldeman, bowled, unrestricted, conde, canvases, boomer, maestro, kiribati,
# Nearest to rise: fucked, equ, delray, described, innovation, christoph, discern, shout,
# Nearest to stage: definition, hopelessness, dieu, opponents, unicode, caria, nyasa, gattaca,
# Nearest to articles: constituting, won, budokai, waterston, warmer, deneuve, trappers, oblique,
# Nearest to taking: cavaliers, danny, minos, acylation, our, auratus, pulley, princetown,
# Nearest to quite: rowed, malky, elective, unprecedented, nau, stuff, originates, autoimmunity,
# Nearest to recorded: kumasi, factors, toes, dictate, lucie, bamileke, lab, majorities,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 12.6692 0.4141 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 12.5908 0.4106 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 12.4916 0.4066 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 12.4636 0.3901 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 12.3090 0.3891 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 12.2755 0.3911 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 12.1683 0.3933 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 12.0217 0.3866 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 12.0221 0.3767 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 12.0305 0.3767 sec/batch
# Nearest to most: of, and, as, that, in, a, to, is,
# Nearest to but: in, the, to, and, for, on, of, is,
# Nearest to for: of, a, the, and, is, in, to, s,
# Nearest to as: the, a, of, to, and, in, with, that,
# Nearest to this: in, and, the, to, of, that, a, s,
# Nearest to system: baird, fairhair, risch, hornblower, frequented, aspartame, eyewitnesses, bohlen,
# Nearest to they: receded, hypothesizing, for, is, blows, irrational, vegetarianism, packets,
# Nearest to some: to, a, of, and, the, by, that, sputnik,
# Nearest to units: lollards, payroll, acquisitions, seto, presume, discs, uther, includes,
# Nearest to hit: haldeman, bowled, unrestricted, canvases, conde, map, maestro, kiribati,
# Nearest to rise: fucked, described, delray, equ, christoph, kuti, discern, shout,
# Nearest to stage: definition, hopelessness, dieu, unicode, caria, opponents, nyasa, taman,
# Nearest to articles: constituting, oblique, trappers, won, waterston, warmer, budokai, deneuve,
# Nearest to taking: cavaliers, danny, minos, colorado, our, auratus, ye, habermas,
# Nearest to quite: rowed, elective, stuff, malky, serrano, unprecedented, autoimmunity, nau,
# Nearest to recorded: kumasi, factors, toes, dictate, lucie, bamileke, lab, majorities,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 11.9973 0.5541 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 11.8792 0.4708 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 11.7970 0.4495 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 11.7243 0.4456 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 11.7028 0.4540 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 11.5709 0.4682 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 11.4633 0.4701 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 11.3896 0.4637 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 11.3469 0.4489 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 11.2334 0.5095 sec/batch
# Nearest to most: of, as, a, the, in, is, to, that,
# Nearest to but: of, to, the, in, as, that, a, and,
# Nearest to for: the, in, a, on, and, of, is, that,
# Nearest to as: of, to, the, in, and, with, a, that,
# Nearest to this: of, the, to, a, that, and, in, for,
# Nearest to system: fairhair, tyrolean, hornblower, baird, risch, narrowly, bohlen, frequented,
# Nearest to they: to, a, as, the, in, be, that, for,
# Nearest to some: to, a, an, and, as, in, with, the,
# Nearest to units: acquisitions, payroll, lollards, seto, powders, presume, uther, simmered,
# Nearest to hit: haldeman, bowled, unrestricted, conde, canvases, map, boomer, simca,
# Nearest to rise: described, delray, fucked, equ, christoph, kuti, discern, shout,
# Nearest to stage: definition, hopelessness, dieu, nyasa, caria, unicode, taman, opponents,
# Nearest to articles: constituting, trappers, won, warmer, oblique, waterston, outdoors, budokai,
# Nearest to taking: danny, cavaliers, minos, christmas, our, habermas, princetown, acylation,
# Nearest to quite: rowed, stuff, autoimmunity, malky, lessing, serrano, elective, tribesmen,
# Nearest to recorded: kumasi, factors, toes, dictate, lucie, lab, bamileke, majorities,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 11.3559 0.4720 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 11.1023 0.5309 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 10.9861 0.5118 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 11.0280 0.5238 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 11.0344 0.4142 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 10.9017 0.4908 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 10.8634 0.7251 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 10.8159 0.8927 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 10.6916 0.8538 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 10.5987 0.8520 sec/batch
# Nearest to most: and, the, as, of, it, in, from, is,
# Nearest to but: of, to, a, and, the, it, that, is,
# Nearest to for: the, to, that, a, of, it, is, in,
# Nearest to as: the, to, of, in, and, this, a, been,
# Nearest to this: the, to, of, is, that, as, by, and,
# Nearest to system: tyrolean, would, often, but, narrowly, membership, risch, hellman,
# Nearest to they: that, it, to, for, are, a, of, is,
# Nearest to some: the, be, this, it, from, and, to, are,
# Nearest to units: payroll, lollards, includes, acquisitions, powders, presume, seto, stapleton,
# Nearest to hit: haldeman, bowled, conde, boomer, longstanding, simca, aware, canvases,
# Nearest to rise: described, delray, fucked, shout, equ, christoph, kuti, appearances,
# Nearest to stage: definition, hopelessness, nyasa, dieu, taman, unicode, caria, opponents,
# Nearest to articles: constituting, trappers, won, warmer, oblique, waterston, outdoors, virtual,
# Nearest to taking: him, christmas, cavaliers, danny, our, princetown, ye, court,
# Nearest to quite: rowed, stuff, malky, lessing, autoimmunity, between, countryman, unprecedented,
# Nearest to recorded: factors, kumasi, toes, dictate, lab, lucie, severe, cear,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 10.5065 0.8590 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 10.6445 0.8514 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 10.4661 0.8473 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 10.5286 0.8391 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 10.5367 0.8177 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 10.2156 0.8254 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 10.4098 0.8233 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 10.2304 0.6022 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 10.0044 0.5300 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 10.1207 0.5348 sec/batch
# Nearest to most: this, the, of, many, and, a, in, have,
# Nearest to but: the, that, to, this, in, not, a, of,
# Nearest to for: the, and, this, to, in, of, a, by,
# Nearest to as: of, in, to, the, that, and, a, some,
# Nearest to this: to, of, in, for, that, the, a, which,
# Nearest to system: many, also, often, they, that, about, an, such,
# Nearest to they: a, that, not, the, this, have, some, these,
# Nearest to some: have, to, the, as, from, a, that, of,
# Nearest to units: payroll, lollards, seto, powders, acquisitions, includes, keypress, oppression,
# Nearest to hit: haldeman, boomer, bowled, map, conde, tabby, priesthoods, longstanding,
# Nearest to rise: described, tacit, fucked, shout, christoph, innovation, elohim, delray,
# Nearest to stage: definition, hopelessness, nyasa, dieu, caria, unicode, geschichte, faux,
# Nearest to articles: constituting, won, trappers, oblique, waterston, warmer, virtual, outdoors,
# Nearest to taking: can, him, like, court, christmas, habermas, our, be,
# Nearest to quite: often, rowed, stuff, tribesmen, lessing, used, all, malky,
# Nearest to recorded: factors, kumasi, toes, cear, dictate, analytical, bamileke, majorities,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 10.1137 0.4631 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 10.0848 0.4961 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 9.9909 0.2235 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 9.8534 0.4780 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 9.8357 0.4731 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 9.7844 0.4916 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 9.7061 0.4447 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 9.7623 0.4572 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 9.5915 0.4078 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 9.4469 0.4946 sec/batch
# Nearest to most: in, of, a, s, be, it, that, the,
# Nearest to but: it, from, for, in, a, to, and, that,
# Nearest to for: a, to, and, from, of, as, in, that,
# Nearest to as: that, a, on, for, in, is, to, of,
# Nearest to this: to, in, it, a, that, or, as, the,
# Nearest to system: are, on, to, which, in, as, for, however,
# Nearest to they: that, their, not, be, are, to, have, for,
# Nearest to some: that, has, as, a, of, it, in, however,
# Nearest to units: payroll, discs, lollards, includes, powders, acquisitions, uther, seto,
# Nearest to hit: map, haldeman, bowled, ingrid, boomer, conde, fundamentalist, king,
# Nearest to rise: described, latter, tacit, abandoned, christoph, several, elohim, deals,
# Nearest to stage: definition, hopelessness, nyasa, dieu, palimpsest, caria, unicode, geschichte,
# Nearest to articles: trappers, won, constituting, oblique, virtual, warmer, waterston, intelligences,
# Nearest to taking: court, him, written, sent, our, where, establishment, white,
# Nearest to quite: they, any, published, would, by, are, that, stuff,
# Nearest to recorded: factors, kumasi, toes, parodied, majorities, masterplan, bamileke, dictate,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 9.4708 0.4106 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 9.5205 0.4270 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 9.3135 0.4339 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 9.1633 0.4651 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 9.1839 0.3876 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 9.2561 0.3978 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 9.3202 0.4140 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 9.1844 0.4340 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 8.9945 0.4341 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 9.0283 0.5709 sec/batch
# Nearest to most: and, of, a, that, are, to, is, other,
# Nearest to but: it, the, a, as, and, in, be, to,
# Nearest to for: and, the, of, a, in, is, that, not,
# Nearest to as: the, of, a, to, and, are, is, in,
# Nearest to this: that, is, it, a, of, not, to, and,
# Nearest to system: and, is, which, of, are, an, this, these,
# Nearest to they: of, not, the, and, some, a, for, have,
# Nearest to some: of, the, are, it, and, they, as, that,
# Nearest to units: lost, discs, payroll, includes, remain, lollards, powders, uther,
# Nearest to hit: map, boomer, take, haldeman, bowled, longstanding, next, buildings,
# Nearest to rise: although, upon, him, latter, subject, having, described, sometimes,
# Nearest to stage: definition, nyasa, hopelessness, palimpsest, opponents, caria, altruistically, washtenaw,
# Nearest to articles: trappers, oblique, virtual, warmer, denmark, source, won, constituting,
# Nearest to taking: written, those, should, entire, more, be, which, any,
# Nearest to quite: would, being, been, and, are, non, much, other,
# Nearest to recorded: factors, must, full, kumasi, parodied, range, compelling, shift,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 9.1341 0.5253 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 9.0665 0.6620 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 8.7202 0.5517 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 8.8579 0.4228 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 8.8683 0.4505 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 8.7399 0.6551 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 8.7710 0.5422 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 8.8315 0.5005 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 8.3849 0.5123 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 8.6104 0.5223 sec/batch
# Nearest to most: a, in, the, is, for, and, of, from,
# Nearest to but: the, in, as, that, a, and, all, to,
# Nearest to for: the, in, a, of, to, is, and, on,
# Nearest to as: the, in, of, with, which, for, was, that,
# Nearest to this: of, that, is, not, the, to, with, a,
# Nearest to system: to, the, is, use, a, given, for, other,
# Nearest to they: a, that, and, the, their, which, have, as,
# Nearest to some: is, and, a, an, that, to, the, their,
# Nearest to units: remain, lost, public, discs, near, growing, lollards, payroll,
# Nearest to hit: map, take, upon, boomer, out, king, population, middle,
# Nearest to rise: th, before, also, example, having, in, this, may,
# Nearest to stage: cases, concept, put, young, definition, considered, design, when,
# Nearest to articles: themselves, independent, describe, although, denmark, meaning, fact, trappers,
# Nearest to taking: however, at, same, s, early, and, been, is,
# Nearest to quite: while, non, same, on, be, in, through, although,
# Nearest to recorded: two, new, s, made, factors, at, more, there,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 8.6254 0.5037 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 8.4045 0.5351 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 8.4487 0.4138 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 8.4813 0.4021 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 8.3078 0.4973 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 8.2489 0.4700 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 8.2620 0.5458 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 8.4472 0.4892 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 8.2779 0.5386 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 8.2037 0.5182 sec/batch
# Nearest to most: the, to, in, a, as, it, and, its,
# Nearest to but: as, to, a, it, however, is, of, be,
# Nearest to for: is, to, of, and, the, it, as, with,
# Nearest to as: the, is, of, a, to, not, have, that,
# Nearest to this: a, is, and, the, to, that, of, be,
# Nearest to system: it, that, is, only, have, not, any, but,
# Nearest to they: as, that, to, a, and, have, by, not,
# Nearest to some: and, have, not, the, a, is, as, has,
# Nearest to units: remain, lost, its, now, million, beginning, near, were,
# Nearest to hit: map, upon, population, close, nations, influential, zero, end,
# Nearest to rise: this, early, between, and, important, religious, the, before,
# Nearest to stage: when, significant, certain, so, term, this, use, on,
# Nearest to articles: describe, though, still, rather, widely, independent, although, physical,
# Nearest to taking: that, as, been, should, this, have, to, from,
# Nearest to quite: used, with, by, are, use, not, different, all,
# Nearest to recorded: on, their, first, moved, at, was, in, into,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 8.4757 0.5294 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 7.9191 0.5081 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 8.2615 0.5186 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 8.1102 0.4907 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 7.8913 0.4343 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 8.0155 0.3788 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 8.0514 0.4682 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 8.0322 0.4484 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 7.9757 0.0739 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 7.8267 0.3890 sec/batch
# Nearest to most: as, to, of, are, an, is, the, in,
# Nearest to but: as, which, to, a, is, that, have, into,
# Nearest to for: is, and, as, of, in, their, that, an,
# Nearest to as: a, in, of, that, are, for, and, some,
# Nearest to this: their, other, be, that, as, some, of, it,
# Nearest to system: systems, any, this, are, available, is, as, development,
# Nearest to they: to, a, the, that, have, their, of, been,
# Nearest to some: that, as, a, to, this, of, is, other,
# Nearest to units: remain, either, to, a, considered, countries, major, beginning,
# Nearest to hit: re, entirely, first, named, rules, history, s, by,
# Nearest to rise: as, to, their, in, of, many, is, a,
# Nearest to stage: may, sometimes, significant, well, for, however, home, associated,
# Nearest to articles: people, describe, reasons, question, often, though, aspects, as,
# Nearest to taking: their, to, a, by, that, they, which, of,
# Nearest to quite: different, as, are, is, have, a, not, it,
# Nearest to recorded: a, s, in, with, at, had, through, own,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 7.8913 0.3960 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 7.9257 0.3869 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 7.7814 0.4042 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 7.8740 0.4259 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 7.6559 0.4177 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 7.5927 0.4032 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 7.6069 0.5090 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 7.6301 0.4382 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 7.5690 0.4483 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 7.2362 0.4635 sec/batch
# Nearest to most: in, the, of, and, is, to, a, even,
# Nearest to but: in, of, to, by, the, and, for, other,
# Nearest to for: and, to, of, an, in, is, the, they,
# Nearest to as: of, to, and, a, the, in, which, other,
# Nearest to this: be, is, it, a, as, of, to, that,
# Nearest to system: be, its, or, a, as, to, other, systems,
# Nearest to they: to, other, for, of, in, and, that, be,
# Nearest to some: it, such, other, more, is, may, to, or,
# Nearest to units: although, during, operation, both, as, terms, did, major,
# Nearest to hit: rules, play, first, where, all, time, top, already,
# Nearest to rise: and, in, as, to, with, the, had, has,
# Nearest to stage: as, has, many, for, well, when, had, use,
# Nearest to articles: religion, groups, not, language, ideas, list, rule, continued,
# Nearest to taking: could, as, the, to, that, while, of, those,
# Nearest to quite: be, is, this, often, also, to, very, as,
# Nearest to recorded: in, was, of, s, a, since, all, had,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 7.3776 0.4651 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 7.4002 0.4998 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 7.5429 0.3759 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 7.5526 0.3832 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 7.2687 0.3778 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 7.3192 0.3772 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 7.3628 0.3781 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 7.3994 0.3775 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 7.1037 0.3845 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 7.1729 0.3800 sec/batch
# Nearest to most: to, a, more, or, as, it, the, in,
# Nearest to but: to, the, in, have, of, their, or, and,
# Nearest to for: the, and, in, to, which, a, of, it,
# Nearest to as: to, the, in, and, or, not, all, that,
# Nearest to this: the, to, a, that, it, or, have, be,
# Nearest to system: is, be, are, systems, or, which, to, more,
# Nearest to they: to, or, the, a, that, but, such, in,
# Nearest to some: or, to, as, more, such, the, they, it,
# Nearest to units: its, many, being, where, are, countries, is, reached,
# Nearest to hit: top, played, out, play, home, up, ever, record,
# Nearest to rise: the, in, and, they, of, with, which, a,
# Nearest to stage: first, in, for, at, during, and, the, was,
# Nearest to articles: language, thought, not, of, history, information, first, accepted,
# Nearest to taking: the, in, of, any, and, both, to, which,
# Nearest to quite: this, as, often, or, however, used, more, that,
# Nearest to recorded: before, in, to, the, s, it, about, popular,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 7.2228 0.3829 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 7.1918 0.3780 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 7.1562 0.3801 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 7.2780 0.3777 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 7.0054 0.3788 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 6.9593 0.3801 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 7.1690 0.3856 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 6.9826 0.3834 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 7.0459 0.3804 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 7.0272 0.3783 sec/batch
# Nearest to most: a, for, the, to, as, of, this, that,
# Nearest to but: on, the, with, which, in, this, to, that,
# Nearest to for: to, a, the, that, is, this, as, on,
# Nearest to as: a, to, the, on, this, that, in, it,
# Nearest to this: that, as, is, a, for, not, however, the,
# Nearest to system: be, a, more, systems, for, used, is, provide,
# Nearest to they: that, the, as, it, this, a, which, to,
# Nearest to some: is, the, which, to, not, a, have, be,
# Nearest to units: is, its, are, given, left, which, capable, it,
# Nearest to hit: record, play, played, home, at, recorded, run, playing,
# Nearest to rise: the, of, see, and, into, at, a, which,
# Nearest to stage: on, more, in, changed, been, by, including, but,
# Nearest to articles: see, article, official, links, history, discussion, on, traditional,
# Nearest to taking: the, a, to, and, which, on, by, in,
# Nearest to quite: not, that, because, is, be, most, some, fact,
# Nearest to recorded: on, first, at, live, see, included, by, before,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 7.0575 0.3852 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 6.7167 0.3805 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 6.8708 0.3785 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 6.9323 0.3833 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 6.9143 0.3856 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 6.9039 0.3791 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 7.1358 0.3749 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 6.6688 0.3763 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 6.9103 0.3768 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 6.9946 0.3743 sec/batch
# Nearest to most: and, the, by, of, as, in, to, more,
# Nearest to but: to, of, and, in, by, as, the, it,
# Nearest to for: of, to, a, the, as, this, have, and,
# Nearest to as: a, some, to, or, that, the, have, it,
# Nearest to this: it, be, to, that, is, for, have, of,
# Nearest to system: systems, it, is, a, for, be, are, use,
# Nearest to they: that, it, as, to, have, this, of, not,
# Nearest to some: as, or, have, a, not, this, of, the,
# Nearest to units: it, its, which, the, level, number, result, unit,
# Nearest to hit: home, record, played, off, success, at, won, appeared,
# Nearest to rise: and, fall, of, the, most, in, important, more,
# Nearest to stage: the, on, best, a, with, made, s, an,
# Nearest to articles: see, article, by, the, has, on, about, of,
# Nearest to taking: of, to, the, as, all, a, by, from,
# Nearest to quite: that, not, these, it, or, this, they, therefore,
# Nearest to recorded: at, s, on, last, with, the, before, in,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 6.6502 0.3804 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 6.7098 0.3785 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 6.7491 0.3826 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 6.7741 0.3769 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 6.8198 0.3767 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 6.6023 0.3462 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 6.7298 0.3783 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 6.7556 0.3801 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 6.6069 0.4754 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 6.7114 0.4234 sec/batch
# Nearest to most: the, to, as, has, however, many, with, which,
# Nearest to but: to, that, as, the, their, it, a, for,
# Nearest to for: a, an, to, the, as, and, in, with,
# Nearest to as: in, some, a, the, for, to, of, an,
# Nearest to this: a, an, to, be, or, is, that, for,
# Nearest to system: systems, is, this, based, developed, application, technology, existing,
# Nearest to they: to, their, that, it, not, some, however, as,
# Nearest to some: as, or, have, is, it, to, that, other,
# Nearest to units: unit, generally, is, a, are, be, some, usually,
# Nearest to hit: record, played, home, first, s, featured, cover, playing,
# Nearest to rise: in, as, while, which, the, this, is, and,
# Nearest to stage: as, with, first, but, many, been, an, it,
# Nearest to articles: history, that, of, traditional, views, see, others, article,
# Nearest to taking: to, a, that, have, but, as, would, the,
# Nearest to quite: be, have, it, to, these, than, a, this,
# Nearest to recorded: and, before, s, first, in, was, with, as,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 6.5994 0.4542 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 6.4447 0.4350 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 6.5556 0.3841 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 6.5599 0.3816 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 6.5029 0.3852 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 6.2896 0.3794 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 6.2823 0.3814 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 6.3713 0.3888 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 6.4799 0.4274 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 6.4702 0.4754 sec/batch
# Nearest to most: in, of, more, these, such, and, also, with,
# Nearest to but: to, have, there, in, of, the, that, as,
# Nearest to for: to, an, of, and, a, in, with, be,
# Nearest to as: to, in, and, a, the, of, with, which,
# Nearest to this: is, that, not, be, have, or, to, a,
# Nearest to system: systems, information, access, developed, be, data, based, each,
# Nearest to they: to, have, a, as, but, either, them, way,
# Nearest to some: to, as, more, have, of, not, other, in,
# Nearest to units: unit, due, its, is, large, of, rest, generally,
# Nearest to hit: play, player, players, home, featured, game, playing, run,
# Nearest to rise: the, in, and, of, on, while, also, still,
# Nearest to stage: and, as, many, on, in, a, well, takes,
# Nearest to articles: article, modern, see, there, among, and, of, considered,
# Nearest to taking: to, of, as, an, when, general, and, with,
# Nearest to quite: not, however, are, such, more, this, or, to,
# Nearest to recorded: and, up, s, was, records, first, rock, on,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 6.3549 0.4345 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 6.3262 0.4369 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 6.3568 0.4033 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 6.4596 0.4001 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 6.3012 0.4923 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 6.1234 0.6231 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 6.3282 0.7707 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 6.2662 0.7654 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 6.2258 0.4416 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 6.3341 0.3836 sec/batch
# Nearest to most: a, it, to, through, its, the, with, in,
# Nearest to but: to, the, of, have, as, in, their, those,
# Nearest to for: it, the, a, to, of, with, as, and,
# Nearest to as: a, to, that, it, the, of, by, an,
# Nearest to this: a, is, that, to, not, or, as, the,
# Nearest to system: systems, application, different, use, basic, information, access, needed,
# Nearest to they: to, will, as, that, a, other, them, their,
# Nearest to some: not, these, as, or, which, with, a, other,
# Nearest to units: large, is, are, determined, range, lower, unit, consists,
# Nearest to hit: played, play, featured, cover, home, recorded, player, record,
# Nearest to rise: of, and, the, as, other, on, to, many,
# Nearest to stage: a, of, in, been, with, and, also, for,
# Nearest to articles: article, online, history, topics, includes, about, see, work,
# Nearest to taking: to, as, which, by, of, the, all, several,
# Nearest to quite: this, fact, a, is, as, and, so, it,
# Nearest to recorded: rock, movie, recording, records, album, music, record, hit,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 6.1419 0.3871 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 6.0549 0.4383 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 6.2865 0.4188 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 6.0975 0.4127 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 6.1469 0.4590 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 6.1408 0.4705 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 6.2329 0.4360 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 5.9398 0.4655 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 6.0004 0.3822 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 5.9693 0.4481 sec/batch
# Nearest to most: it, and, a, to, as, through, for, the,
# Nearest to but: a, to, would, the, that, by, their, however,
# Nearest to for: a, to, the, and, as, of, an, it,
# Nearest to as: to, of, and, the, in, with, a, by,
# Nearest to this: is, that, be, it, because, are, have, not,
# Nearest to system: use, such, systems, can, for, programs, are, used,
# Nearest to they: that, to, it, would, not, a, have, so,
# Nearest to some: it, a, to, has, which, the, other, have,
# Nearest to units: line, which, it, range, consists, is, are, more,
# Nearest to hit: run, record, home, player, off, night, played, team,
# Nearest to rise: with, of, as, to, and, fall, on, from,
# Nearest to stage: when, both, well, started, as, role, in, with,
# Nearest to articles: links, external, article, history, encyclopedia, references, historical, includes,
# Nearest to taking: to, a, the, with, that, this, would, when,
# Nearest to quite: it, not, that, is, a, to, because, this,
# Nearest to recorded: records, record, style, at, s, rock, back, music,
# Epoch 5/10 Iteration: 22100 Avg. Training loss: 6.1025 0.4195 sec/batch
# Epoch 5/10 Iteration: 22200 Avg. Training loss: 6.1292 0.4875 sec/batch
# Epoch 5/10 Iteration: 22300 Avg. Training loss: 6.2264 0.4204 sec/batch
# Epoch 5/10 Iteration: 22400 Avg. Training loss: 6.1487 0.5012 sec/batch
# Epoch 5/10 Iteration: 22500 Avg. Training loss: 5.9281 0.4552 sec/batch
# Epoch 5/10 Iteration: 22600 Avg. Training loss: 6.1431 0.4112 sec/batch
# Epoch 5/10 Iteration: 22700 Avg. Training loss: 5.9681 0.4644 sec/batch
# Epoch 5/10 Iteration: 22800 Avg. Training loss: 5.9111 0.4744 sec/batch
# Epoch 5/10 Iteration: 22900 Avg. Training loss: 5.9275 0.4590 sec/batch
# Epoch 5/10 Iteration: 23000 Avg. Training loss: 6.0524 0.4745 sec/batch
# Nearest to most: to, the, as, other, a, an, for, now,
# Nearest to but: to, the, as, it, a, which, have, into,
# Nearest to for: a, to, as, is, the, that, an, other,
# Nearest to as: to, the, of, a, that, for, in, however,
# Nearest to this: that, it, have, to, for, any, more, not,
# Nearest to system: systems, access, use, used, data, application, developed, programs,
# Nearest to they: to, that, some, the, which, not, however, but,
# Nearest to some: other, to, that, as, or, not, have, is,
# Nearest to units: unit, each, are, likely, scale, is, used, internal,
# Nearest to hit: record, home, cover, play, played, featured, career, fans,
# Nearest to rise: from, in, fall, the, about, remains, of, now,
# Nearest to stage: recently, s, movie, audience, a, show, on, late,
# Nearest to articles: links, online, history, external, book, publications, article, complete,
# Nearest to taking: to, that, a, with, as, of, but, the,
# Nearest to quite: it, some, this, might, even, such, that, often,
# Nearest to recorded: band, album, rock, record, records, recording, playing, s,
# Epoch 5/10 Iteration: 23100 Avg. Training loss: 6.0170 0.4525 sec/batch
# Epoch 6/10 Iteration: 23200 Avg. Training loss: 5.9779 0.3191 sec/batch
# Epoch 6/10 Iteration: 23300 Avg. Training loss: 5.9446 0.4526 sec/batch
# Epoch 6/10 Iteration: 23400 Avg. Training loss: 5.9833 0.4610 sec/batch
# Epoch 6/10 Iteration: 23500 Avg. Training loss: 5.8976 0.4537 sec/batch
# Epoch 6/10 Iteration: 23600 Avg. Training loss: 5.9036 0.4600 sec/batch
# Epoch 6/10 Iteration: 23700 Avg. Training loss: 5.9388 0.4523 sec/batch
# Epoch 6/10 Iteration: 23800 Avg. Training loss: 5.8174 0.4499 sec/batch
# Epoch 6/10 Iteration: 23900 Avg. Training loss: 5.8010 0.4627 sec/batch
# Epoch 6/10 Iteration: 24000 Avg. Training loss: 5.8401 0.4700 sec/batch
# Nearest to most: with, it, as, for, in, is, of, many,
# Nearest to but: to, the, that, from, it, by, not, as,
# Nearest to for: a, with, it, to, in, and, as, an,
# Nearest to as: an, from, the, a, with, and, many, of,
# Nearest to this: that, it, be, for, a, an, any, no,
# Nearest to system: systems, data, users, available, using, multiple, application, implemented,
# Nearest to they: to, which, that, even, their, been, it, would,
# Nearest to some: be, is, it, that, a, may, are, have,
# Nearest to units: unit, its, generally, size, are, is, each, more,
# Nearest to hit: play, played, home, team, game, players, record, player,
# Nearest to rise: and, from, the, they, while, whose, of, which,
# Nearest to stage: a, as, audience, and, on, in, enough, s,
# Nearest to articles: views, see, discussion, article, publication, religious, history, others,
# Nearest to taking: to, having, that, of, while, their, the, by,
# Nearest to quite: have, difficult, more, these, they, however, often, or,
# Nearest to recorded: album, song, band, songs, rock, records, early, recording,
# Epoch 6/10 Iteration: 24100 Avg. Training loss: 5.8404 0.4689 sec/batch
# Epoch 6/10 Iteration: 24200 Avg. Training loss: 5.6660 0.4608 sec/batch
# Epoch 6/10 Iteration: 24300 Avg. Training loss: 5.6300 0.4582 sec/batch
# Epoch 6/10 Iteration: 24400 Avg. Training loss: 5.6759 0.4506 sec/batch
# Epoch 6/10 Iteration: 24500 Avg. Training loss: 5.7689 0.4488 sec/batch
# Epoch 6/10 Iteration: 24600 Avg. Training loss: 5.8205 0.4478 sec/batch
# Epoch 6/10 Iteration: 24700 Avg. Training loss: 5.7355 0.4512 sec/batch
# Epoch 6/10 Iteration: 24800 Avg. Training loss: 5.7014 0.4854 sec/batch
# Epoch 6/10 Iteration: 24900 Avg. Training loss: 5.6588 0.4719 sec/batch
# Epoch 6/10 Iteration: 25000 Avg. Training loss: 5.8076 0.5036 sec/batch
# Nearest to most: the, of, as, have, to, more, and, from,
# Nearest to but: to, it, the, and, that, so, these, in,
# Nearest to for: to, the, an, with, a, as, and, have,
# Nearest to as: to, the, a, this, an, is, which, that,
# Nearest to this: that, be, a, to, any, such, as, is,
# Nearest to system: systems, use, access, information, implemented, available, tasks, for,
# Nearest to they: them, the, to, in, all, their, so, give,
# Nearest to some: are, or, this, as, other, can, such, which,
# Nearest to units: unit, range, is, large, cost, low, operate, small,
# Nearest to hit: played, record, play, players, hits, player, home, team,
# Nearest to rise: and, the, being, in, of, from, on, to,
# Nearest to stage: on, time, with, best, the, would, and, in,
# Nearest to articles: article, term, modern, see, encyclopedia, history, academic, publication,
# Nearest to taking: to, the, of, there, as, all, and, by,
# Nearest to quite: it, which, have, these, be, this, some, that,
# Nearest to recorded: song, album, band, first, records, was, famous, recording,
# Epoch 6/10 Iteration: 25100 Avg. Training loss: 5.7751 0.5280 sec/batch
# Epoch 6/10 Iteration: 25200 Avg. Training loss: 5.5607 0.4007 sec/batch
# Epoch 6/10 Iteration: 25300 Avg. Training loss: 5.6247 0.4290 sec/batch
# Epoch 6/10 Iteration: 25400 Avg. Training loss: 5.6991 0.4424 sec/batch
# Epoch 6/10 Iteration: 25500 Avg. Training loss: 5.5831 0.4247 sec/batch
# Epoch 6/10 Iteration: 25600 Avg. Training loss: 5.7639 0.4505 sec/batch
# Epoch 6/10 Iteration: 25700 Avg. Training loss: 5.6592 0.4472 sec/batch
# Epoch 6/10 Iteration: 25800 Avg. Training loss: 5.4259 0.4506 sec/batch
# Epoch 6/10 Iteration: 25900 Avg. Training loss: 5.6288 0.4474 sec/batch
# Epoch 6/10 Iteration: 26000 Avg. Training loss: 5.6423 0.4503 sec/batch
# Nearest to most: the, a, of, to, many, it, from, and,
# Nearest to but: to, and, of, as, in, a, the, which,
# Nearest to for: a, has, it, be, to, an, have, this,
# Nearest to as: a, that, this, and, it, often, some, of,
# Nearest to this: a, that, as, be, have, not, which, it,
# Nearest to system: systems, use, multiple, for, access, using, data, each,
# Nearest to they: to, that, this, not, as, a, these, when,
# Nearest to some: as, these, has, that, be, or, a, have,
# Nearest to units: unit, range, large, is, smaller, are, low, size,
# Nearest to hit: record, played, fans, hits, playing, cover, recorded, success,
# Nearest to rise: of, with, and, a, by, its, which, in,
# Nearest to stage: a, by, few, success, once, well, up, but,
# Nearest to articles: online, article, external, encyclopedia, topics, page, links, org,
# ...
# Nearest to as: the, and, in, to, an, with, of, from,
# Nearest to this: be, to, that, it, thus, even, these, rather,
# Nearest to system: systems, access, operating, hardware, data, available, provides, user,
# Nearest to they: to, them, their, would, but, away, that, been,
# Nearest to some: other, have, that, as, many, to, these, more,
# Nearest to units: unit, si, density, measurement, line, metre, range, its,
# Nearest to hit: hits, hitting, play, players, played, playing, career, game,
# Nearest to rise: fall, throughout, period, great, almost, beginning, collapse, century,
# Nearest to stage: appeared, cover, film, performers, best, audiences, credited, produced,
# Nearest to articles: topics, encyclopedia, article, archives, publications, discussion, org, community,
# Nearest to taking: to, by, having, who, was, previous, their, but,
# Nearest to quite: it, variety, frequently, some, more, being, often, have,
# Nearest to recorded: recordings, album, band, recording, rock, songs, song, records,
# Epoch 9/10 Iteration: 38100 Avg. Training loss: 4.6764 0.3833 sec/batch
# Epoch 9/10 Iteration: 38200 Avg. Training loss: 4.6371 0.5335 sec/batch
# Epoch 9/10 Iteration: 38300 Avg. Training loss: 4.6789 0.5333 sec/batch
# Epoch 9/10 Iteration: 38400 Avg. Training loss: 4.7167 0.5056 sec/batch
# Epoch 9/10 Iteration: 38500 Avg. Training loss: 4.7969 0.5126 sec/batch
# Epoch 9/10 Iteration: 38600 Avg. Training loss: 4.6989 0.5091 sec/batch
# Epoch 9/10 Iteration: 38700 Avg. Training loss: 4.7074 0.5344 sec/batch
# Epoch 9/10 Iteration: 38800 Avg. Training loss: 4.6980 0.5145 sec/batch
# Epoch 9/10 Iteration: 38900 Avg. Training loss: 4.8234 0.5078 sec/batch
# Epoch 9/10 Iteration: 39000 Avg. Training loss: 4.7964 0.5103 sec/batch
# Nearest to most: more, which, such, through, and, are, some, these,
# Nearest to but: to, have, that, a, the, however, than, thus,
# Nearest to for: a, an, to, and, the, has, such, on,
# Nearest to as: and, the, not, in, of, an, this, that,
# Nearest to this: that, not, it, such, any, as, same, be,
# Nearest to system: systems, use, access, application, implemented, source, provide, tasks,
# Nearest to they: them, their, to, even, before, however, but, have,
# Nearest to some: or, are, other, which, many, these, it, often,
# Nearest to units: unit, weights, si, measurement, density, quantity, per, operate,
# Nearest to hit: hits, hitting, played, play, lineup, playing, players, ball,
# Nearest to rise: of, almost, although, while, and, still, into, period,
# Nearest to stage: film, appeared, best, appearing, featured, actors, plays, audiences,
# Nearest to articles: topics, online, links, external, encyclopedia, comprehensive, references, archives,
# Nearest to taking: to, since, an, in, and, already, but, a,
# Nearest to quite: some, often, though, but, manner, which, sometimes, because,
# Nearest to recorded: songs, album, band, recordings, albums, recording, song, records,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 4.6065 0.5163 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 4.6902 0.5157 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 4.7647 0.6733 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 4.6530 0.6207 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 4.7783 0.5102 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 4.6611 0.6087 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 4.6238 0.5858 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 4.7376 0.6550 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 4.7073 0.5568 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 4.6926 0.5150 sec/batch
# Nearest to most: many, as, a, some, more, other, such, in,
# Nearest to but: to, their, the, with, many, have, they, in,
# Nearest to for: a, use, an, all, also, by, such, non,
# Nearest to as: of, a, which, this, with, in, the, and,
# Nearest to this: a, that, not, as, which, the, have, of,
# Nearest to system: systems, use, access, additional, available, operating, transfer, limited,
# Nearest to they: that, but, to, their, them, so, have, because,
# Nearest to some: many, a, not, have, other, most, but, as,
# Nearest to units: unit, weights, si, mobility, density, per, range, larger,
# Nearest to hit: hits, hitting, played, success, play, playing, lineup, weeks,
# Nearest to rise: of, and, decades, its, in, the, as, period,
# Nearest to stage: pop, appearing, show, film, scenes, plays, best, scene,
# Nearest to articles: links, online, encyclopedia, external, page, topics, org, article,
# Nearest to taking: to, after, the, however, since, by, but, were,
# Nearest to quite: which, often, few, so, it, some, even, have,
# Nearest to recorded: album, band, songs, recording, pop, rock, albums, recordings,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 4.6809 0.5904 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 4.7187 0.5088 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 4.5677 0.5133 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 4.6244 0.5074 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 4.6207 0.5137 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 4.6589 0.5458 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 4.7325 0.5016 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 4.7784 0.5268 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 4.7743 0.5717 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 4.5895 0.5107 sec/batch
# Nearest to most: the, in, and, by, also, has, from, as,
# Nearest to but: would, the, to, by, however, it, they, although,
# Nearest to for: and, a, by, of, the, to, s, an,
# Nearest to as: of, the, and, by, a, have, to, which,
# Nearest to this: that, it, a, to, thus, be, which, not,
# Nearest to system: systems, provides, application, limited, operating, use, access, programs,
# Nearest to they: their, would, it, be, that, have, a, as,
# Nearest to some: have, such, often, these, not, or, that, as,
# Nearest to units: unit, si, weights, operations, density, capability, mobility, measures,
# Nearest to hit: hits, hitting, off, played, lineup, players, record, playing,
# Nearest to rise: the, western, due, fall, important, during, of, great,
# Nearest to stage: filming, album, rock, film, appearing, show, played, debut,
# Nearest to articles: encyclopedia, online, article, topics, org, information, links, external,
# Nearest to taking: to, time, would, which, holding, with, since, a,
# Nearest to quite: similar, than, extremely, noticeable, like, usually, often, some,
# Nearest to recorded: band, rock, album, songs, records, song, albums, cover,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 4.6590 0.5289 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 4.6427 0.5011 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 4.5599 0.4477 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 4.5896 0.5043 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 4.6526 0.4221 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 4.6958 0.3810 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 4.6855 0.2208 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 4.6159 0.3984 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 4.6537 0.4085 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 4.6462 0.3881 sec/batch
# Nearest to most: other, has, many, although, with, in, also, some,
# Nearest to but: not, that, to, which, their, them, they, a,
# Nearest to for: an, a, on, to, in, all, by, s,
# Nearest to as: and, some, a, which, or, have, many, that,
# Nearest to this: a, not, be, an, so, same, that, to,
# Nearest to system: systems, basic, operating, applications, application, via, implemented, allows,
# Nearest to they: them, to, their, that, not, been, did, a,
# Nearest to some: these, as, many, have, other, that, or, very,
# Nearest to units: unit, si, measurement, weights, metre, range, measured, size,
# Nearest to hit: hits, hitting, tracks, played, record, scored, players, missed,
# Nearest to rise: the, of, during, and, period, which, from, around,
# Nearest to stage: best, feature, film, show, audiences, crew, big, series,
# Nearest to articles: comprehensive, encyclopedia, topics, journals, discussion, website, topic, article,
# Nearest to taking: a, did, to, would, will, so, with, that,
# Nearest to quite: very, often, variety, have, some, generally, tend, less,
# Nearest to recorded: album, rock, band, song, records, debut, night, concert,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 4.6124 0.3847 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 4.6855 0.3867 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 4.6147 0.3826 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 4.5218 0.3835 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 4.5664 0.5400 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 4.6523 0.4974 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 4.5530 0.7544 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 4.4220 0.4893 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 4.5151 0.7077 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 4.5234 0.7454 sec/batch
# Nearest to most: in, other, as, the, some, has, many, have,
# Nearest to but: to, the, their, that, been, have, them, because,
# Nearest to for: an, a, to, in, and, the, all, has,
# Nearest to as: in, to, a, and, which, the, has, of,
# Nearest to this: be, a, that, it, as, which, not, to,
# Nearest to system: systems, implemented, available, limited, provided, operating, based, provide,
# Nearest to they: would, them, their, to, when, be, even, because,
# Nearest to some: other, have, to, as, more, these, not, that,
# Nearest to units: unit, si, weights, capability, operations, upgraded, range, deployed,
# Nearest to hit: hits, hitting, players, play, score, scored, fans, playing,
# Nearest to rise: during, the, beginning, about, around, into, from, due,
# Nearest to stage: best, audiences, credited, pop, film, too, very, scene,
# Nearest to articles: article, topics, org, links, encyclopedia, includes, comprehensive, history,
# Nearest to taking: them, up, before, would, they, when, attempting, out,
# Nearest to quite: often, whole, more, have, though, some, considered, very,
# Nearest to recorded: rock, band, album, song, songs, recordings, cover, records,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 4.5800 0.7355 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 4.5403 0.6752 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 4.5504 0.6677 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 4.5300 0.6821 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 4.5908 0.6809 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 4.6437 0.6799 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 4.4775 0.6722 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 4.4757 0.6771 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 4.5901 0.6711 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 4.5368 0.6827 sec/batch
# Nearest to most: some, in, more, such, with, it, many, these,
# Nearest to but: their, have, them, that, to, however, as, they,
# Nearest to for: in, a, on, use, to, the, an, with,
# Nearest to as: of, the, in, which, that, and, this, but,
# Nearest to this: be, that, is, such, it, which, not, same,
# Nearest to system: systems, provide, application, level, for, directly, implemented, multiple,
# Nearest to they: their, them, but, that, would, to, however, having,
# Nearest to some: most, such, more, or, often, these, generally, many,
# Nearest to units: unit, weights, si, quantity, calculated, equipped, capability, force,
# Nearest to hit: hits, hitting, play, score, struck, shot, off, crowd,
# Nearest to rise: and, about, been, of, from, many, on, in,
# Nearest to stage: film, recorded, best, scene, s, cast, a, performances,
# Nearest to articles: external, topics, links, online, org, website, com, forum,
# Nearest to taking: be, will, that, take, may, give, they, their,
# Nearest to quite: very, appear, often, usually, some, with, such, which,
# Nearest to recorded: rock, band, album, songs, lyrics, singing, recording, song,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 4.5831 0.6885 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 4.5264 0.5489 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 4.4119 0.7203 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 4.5328 0.8082 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 4.5728 0.6835 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 4.4870 0.6829 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 4.5283 0.6754 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 4.5333 0.7138 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 4.4807 0.7246 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 4.4556 0.7379 sec/batch
# Nearest to most: as, in, the, and, a, it, from, other,
# Nearest to but: them, to, not, with, have, their, that, into,
# Nearest to for: a, in, by, to, the, has, an, as,
# Nearest to as: in, the, to, has, and, these, most, a,
# Nearest to this: that, is, not, be, which, it, to, common,
# Nearest to system: systems, additional, application, use, applications, available, operating, implementation,
# Nearest to they: to, that, not, their, with, only, being, be,
# Nearest to some: have, these, many, to, as, or, such, more,
# Nearest to units: unit, equipped, infantry, capability, larger, range, operations, si,
# Nearest to hit: hits, hitting, off, scored, got, run, played, runs,
# Nearest to rise: of, vast, from, strong, the, due, through, and,
# Nearest to stage: too, unusual, emotional, ability, involves, whilst, show, scene,
# Nearest to articles: links, external, encyclopedia, article, website, topics, online, comprehensive,
# Nearest to taking: with, time, to, when, resulting, on, the, they,
# Nearest to quite: such, often, actually, than, appear, these, like, few,
# Nearest to recorded: rock, album, band, music, cover, singing, songs, charts,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 4.4795 0.6909 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 4.4650 0.6811 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 4.5756 0.6751 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 4.5811 0.6829 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 4.6759 0.7281 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 4.4495 0.7491 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 4.5346 0.6705 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 4.5039 0.5012 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 4.3851 0.3872 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 4.4759 0.3841 sec/batch
# Nearest to most: in, and, the, more, other, well, as, from,
# Nearest to but: however, to, it, as, not, have, that, even,
# Nearest to for: a, to, an, with, it, this, on, in,
# Nearest to as: these, to, other, in, that, of, have, more,
# Nearest to this: that, it, to, be, however, not, some, the,
# Nearest to system: systems, limited, implemented, available, lines, programs, development, support,
# Nearest to they: that, them, but, not, this, to, all, themselves,
# Nearest to some: these, other, often, this, are, have, different, however,
# Nearest to units: unit, si, weights, metre, measurement, density, nist, size,
# Nearest to hit: hits, hitting, played, career, record, off, fans, success,
# Nearest to rise: of, from, the, and, most, its, important, more,
# Nearest to stage: film, roles, movie, filming, titled, album, favorite, best,
# Nearest to articles: topics, article, external, comprehensive, encyclopedia, org, links, publications,
# Nearest to taking: to, result, when, that, time, with, it, a,
# Nearest to quite: these, are, very, tend, more, though, it, extremely,
# Nearest to recorded: album, band, rock, songs, song, debut, cover, albums,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 4.4615 0.3924 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 4.4736 0.3898 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
#train_graph = tf.Graph()
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)
# /Users/vaidasarmonas/Documents/Udacity/deepLearningNanoDegree/week8/embeddings
# Out:
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# /Users/vaidasarmonas/anaconda2/envs/dlND_tf1/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1021     try:
# -> 1022       return fn(*args)
#    1023     except errors.OpError as e:
#
# /Users/vaidasarmonas/anaconda2/envs/dlND_tf1/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1003                                  feed_dict, fetch_list, target_list,
# -> 1004                                  status, run_metadata)
#    1005
#
# /Users/vaidasarmonas/anaconda2/envs/dlND_tf1/lib/python3.6/contextlib.py in __exit__(self, type, value, traceback)
#      88             try:
# ---> 89                 next(self.gen)
#      90             except StopIteration:
#
# /Users/vaidasarmonas/anaconda2/envs/dlND_tf1/lib/python3.6/site-packages/tensorflow/python/framework/errors_impl.py in raise_exception_on_not_ok_status()
#     465           compat.as_text(pywrap_tensorflow.TF_Message(status)),
# --> 466           pywrap_tensorflow.TF_GetCode(status))
#     467   finally:
#
# NotFoundError: Key Variable/Adam not found in checkpoint
# 	 [[Node: save_1/RestoreV2_1 = RestoreV2[dtypes=[DT_FLOAT], _device="/job:localhost/replica:0/task:0/cpu:0"](_recv_save_1/Const_0, save_1/RestoreV2_1/tensor_names, save_1/RestoreV2_1/shape_and_slices)]]
#
# During handling of the above exception, another exception occurred:
#
# NotFoundError                             Traceback (most recent call last)
# <ipython-input-28-a01beeed3fc9> in <module>()
#       4
#       5 with tf.Session(graph=train_graph) as sess:
# ----> 6     saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
#       7     embed_mat = sess.run(embedding)
#       8 # /Users/vaidasarmonas/Documents/Udacity/deepLearningNanoDegree/week8/embeddings
#
# /Users/vaidasarmonas/anaconda2/envs/dlND_tf1/lib/python3.6/site-packages/tensorflow/python/training/saver.py in restore(self, sess, save_path)
#    1426       return
#    1427     sess.run(self.saver_def.restore_op_name,
# -> 1428              {self.saver_def.filename_tensor_name: save_path})
#    1429
#    1430   @staticmethod
#
# /Users/vaidasarmonas/anaconda2/envs/dlND_tf1/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     765     try:
#     766       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 767                          run_metadata_ptr)
#     768       if run_metadata:
#     769         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /Users/vaidasarmonas/anaconda2/envs/dlND_tf1/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     963     if final_fetches or final_targets:
#     964       results = self._do_run(handle, final_targets, final_fetches,
# --> 965                              feed_dict_string, options, run_metadata)
#     966     else:
#     967       results = []
#
# /Users/vaidasarmonas/anaconda2/envs/dlND_tf1/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1013     if handle is None:
#    1014       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1015                            target_list, options, run_metadata)
#    1016     else:
#    1017       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /Users/vaidasarmonas/anaconda2/envs/dlND_tf1/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1033         except KeyError:
#    1034           pass
# -> 1035       raise type(e)(node_def, op, message)
#    1036
#    1037   def _extend_graph(self):
#
# NotFoundError: Key Variable/Adam not found in checkpoint
# 	 [[Node: save_1/RestoreV2_1 = RestoreV2[dtypes=[DT_FLOAT], _device="/job:localhost/replica:0/task:0/cpu:0"](_recv_save_1/Const_0, save_1/RestoreV2_1/tensor_names, save_1/RestoreV2_1/shape_and_slices)]]
#
# Caused by op 'save_1/RestoreV2_1', defined at:
#   File "/Users/vaidasarmonas/anaconda2/envs/dlND_tf1/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/Users/vaidasarmonas/anaconda2/envs/dlND_tf1/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/Users/vaidasarmonas/anaconda2/envs/dlND_tf1/lib/python3.6/site-packages/ipykernel/__main__.py", line 3, in <module>
#     app.launch_new_instance()
#   File "/Users/vaidasarmonas/anaconda2/envs/dlND_tf1/lib/python3.6/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/Users/vaidasarmonas/anaconda2/envs/dlND_tf1/lib/python3.6/site-packages/ipykernel/kernelapp.py", line 474, in start
#     ioloop.IOLoop.instance().start()
#   File "/Users/vaidasarmonas/anaconda2/envs/dlND_tf1/lib/python3.6/site-packages/zmq/eventloop/ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "/Users/vaidasarmonas/anaconda2/envs/dlND_tf1/lib/python3.6/site-packages/tornado/ioloop.py", line 887, in start
#     handler_func(fd_obj, events)
#   File "/Users/vaidasarmonas/anaconda2/envs/dlND_tf1/lib/python3.6/site-packages/tornado/stack_context.py", line 275, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/Users/vaidasarmonas/anaconda2/envs/dlND_tf1/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "/Users/vaidasarmonas/anaconda2/envs/dlND_tf1/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/Users/vaidasarmonas/anaconda2/envs/dlND_tf1/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "/Users/vaidasarmonas/anaconda2/envs/dlND_tf1/lib/python3.6/site-packages/tornado/stack_context.py", line 275, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/Users/vaidasarmonas/anaconda2/envs/dlND_tf1/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 276, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/Users/vaidasarmonas/anaconda2/envs/dlND_tf1/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 228, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/Users/vaidasarmonas/anaconda2/envs/dlND_tf1/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 390, in execute_request
#     user_expressions, allow_stdin)
#   File "/Users/vaidasarmonas/anaconda2/envs/dlND_tf1/lib/python3.6/site-packages/ipykernel/ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/Users/vaidasarmonas/anaconda2/envs/dlND_tf1/lib/python3.6/site-packages/ipykernel/zmqshell.py", line 501, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/Users/vaidasarmonas/anaconda2/envs/dlND_tf1/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2717, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/Users/vaidasarmonas/anaconda2/envs/dlND_tf1/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2821, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/Users/vaidasarmonas/anaconda2/envs/dlND_tf1/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2881, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-28-a01beeed3fc9>", line 3, in <module>
#     saver = tf.train.Saver()
#   File "/Users/vaidasarmonas/anaconda2/envs/dlND_tf1/lib/python3.6/site-packages/tensorflow/python/training/saver.py", line 1040, in __init__
#     self.build()
#   File "/Users/vaidasarmonas/anaconda2/envs/dlND_tf1/lib/python3.6/site-packages/tensorflow/python/training/saver.py", line 1070, in build
#     restore_sequentially=self._restore_sequentially)
#   File "/Users/vaidasarmonas/anaconda2/envs/dlND_tf1/lib/python3.6/site-packages/tensorflow/python/training/saver.py", line 675, in build
#     restore_sequentially, reshape)
#   File "/Users/vaidasarmonas/anaconda2/envs/dlND_tf1/lib/python3.6/site-packages/tensorflow/python/training/saver.py", line 402, in _AddRestoreOps
#     tensors = self.restore_op(filename_tensor, saveable, preferred_shard)
#   File "/Users/vaidasarmonas/anaconda2/envs/dlND_tf1/lib/python3.6/site-packages/tensorflow/python/training/saver.py", line 242, in restore_op
#     [spec.tensor.dtype])[0])
#   File "/Users/vaidasarmonas/anaconda2/envs/dlND_tf1/lib/python3.6/site-packages/tensorflow/python/ops/gen_io_ops.py", line 668, in restore_v2
#     dtypes=dtypes, name=name)
#   File "/Users/vaidasarmonas/anaconda2/envs/dlND_tf1/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py", line 763, in apply_op
#     op_def=op_def)
#   File "/Users/vaidasarmonas/anaconda2/envs/dlND_tf1/lib/python3.6/site-packages/tensorflow/python/framework/ops.py", line 2327, in create_op
#     original_op=self._default_original_op, op_def=op_def)
#   File "/Users/vaidasarmonas/anaconda2/envs/dlND_tf1/lib/python3.6/site-packages/tensorflow/python/framework/ops.py", line 1226, in __init__
#     self._traceback = _extract_stack()
#
# NotFoundError (see above for traceback): Key Variable/Adam not found in checkpoint
# 	 [[Node: save_1/RestoreV2_1 = RestoreV2[dtypes=[DT_FLOAT], _device="/job:localhost/replica:0/task:0/cpu:0"](_recv_save_1/Const_0, save_1/RestoreV2_1/tensor_names, save_1/RestoreV2_1/shape_and_slices)]]

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
embed_mat[:10, :]
# Out:
# array([[-0.03554971,  0.01125557, -0.04118827, ..., -0.00905577,
#         -0.00365047, -0.02382756],
#        [-0.0178726 ,  0.01393869, -0.01675534, ..., -0.01762283,
#          0.05602714,  0.00436138],
#        [-0.03923443,  0.01726716, -0.01856709, ..., -0.02905127,
#          0.0056226 , -0.0007387 ],
#        ...,
#        [-0.10127924,  0.01416038,  0.02473724, ...,  0.00451312,
#          0.08071758, -0.01328187],
#        [-0.04857953,  0.00950702,  0.06013128, ...,  0.02067756,
#          0.08861037, -0.05660807],
#        [-0.09246647,  0.03071205,  0.0463699 , ...,  0.01844652,
#          0.09917516, -0.01107038]], dtype=float32)

# %%
viz_words = 200
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-9c08601ca5e8> in <module>()
#       1 viz_words = 200
#       2 tsne = TSNE()
# ----> 3 embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])
#
# /Users/vaidasarmonas/anaconda2/envs/dlND_tf1/lib/python3.6/site-packages/sklearn/manifold/t_sne.py in fit_transform(self, X, y)
#     882             Embedding of the training data in low-dimensional space.
#     883         """
# --> 884         embedding = self._fit(X)
#     885         self.embedding_ = embedding
#     886         return self.embedding_
#
# /Users/vaidasarmonas/anaconda2/envs/dlND_tf1/lib/python3.6/site-packages/sklearn/manifold/t_sne.py in _fit(self, X, skip_num_points)
#     787                           X_embedded=X_embedded,
#     788                           neighbors=neighbors_nn,
# --> 789                           skip_num_points=skip_num_points)
#     790
#     791     def _tsne(self, P, degrees_of_freedom, n_samples, random_state,
#
# /Users/vaidasarmonas/anaconda2/envs/dlND_tf1/lib/python3.6/site-packages/sklearn/manifold/t_sne.py in _tsne(self, P, degrees_of_freedom, n_samples, random_state, X_embedded, neighbors, skip_num_points)
#     845         opt_args['it'] = it + 1
#     846         params, kl_divergence, it = _gradient_descent(obj_func, params,
# --> 847                                                       **opt_args)
#     848         if self.verbose:
#     849             print("[t-SNE] KL divergence after %d iterations with early "
#
# /Users/vaidasarmonas/anaconda2/envs/dlND_tf1/lib/python3.6/site-packages/sklearn/manifold/t_sne.py in _gradient_descent(objective, p0, it, n_iter, objective_error, n_iter_check, n_iter_without_progress, momentum, learning_rate, min_gain, min_grad_norm, min_error_diff, verbose, args, kwargs)
#     386     for i in range(it, n_iter):
#     387         new_error, grad = objective(p, *args, **kwargs)
# --> 388         grad_norm = linalg.norm(grad)
#     389
#     390         inc = update * grad >= 0.0
#
# /Users/vaidasarmonas/anaconda2/envs/dlND_tf1/lib/python3.6/site-packages/scipy/linalg/misc.py in norm(a, ord, axis, keepdims)
#     127     """
#     128     # Differs from numpy only in non-finite handling and the use of blas.
# --> 129     a = np.asarray_chkfinite(a)
#     130
#     131     # Only use optimized norms if axis and keepdims are not specified.
#
# /Users/vaidasarmonas/anaconda2/envs/dlND_tf1/lib/python3.6/site-packages/numpy/lib/function_base.py in asarray_chkfinite(a, dtype, order)
#    1213     if a.dtype.char in typecodes['AllFloat'] and not np.isfinite(a).all():
#    1214         raise ValueError(
# -> 1215             "array must not contain infs or NaNs")
#    1216     return a
#    1217
#
# ValueError: array must not contain infs or NaNs

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
